# %% [markdown]
# # Iris Data Set
#
# This data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray. <br/>
# The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width.<br/>
# The below plot uses the first two features. See here for more information on this dataset.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as matpat
from statistics import mean
import numpy as np
import csv
import seaborn as sns
import pandas as pd

# %% [markdown]
# First we will take a look in the CSV file

# %%
with open ('IRIS.csv') as irisCSV:
    readCSV = csv.reader(irisCSV, delimiter =',')
    
    print(irisCSV.read())
# Out:
# 5.1,3.5,1.4,0.2,setosa
# 4.9,3,1.4,0.2,setosa
# 4.7,3.2,1.3,0.2,setosa
# 4.6,3.1,1.5,0.2,setosa
# 5,3.6,1.4,0.2,setosa
# 5.4,3.9,1.7,0.4,setosa
# 4.6,3.4,1.4,0.3,setosa
# 5,3.4,1.5,0.2,setosa
# 4.4,2.9,1.4,0.2,setosa
# 4.9,3.1,1.5,0.1,setosa
# 5.4,3.7,1.5,0.2,setosa
# 4.8,3.4,1.6,0.2,setosa
# 4.8,3,1.4,0.1,setosa
# 4.3,3,1.1,0.1,setosa
# 5.8,4,1.2,0.2,setosa
# 5.7,4.4,1.5,0.4,setosa
# 5.4,3.9,1.3,0.4,setosa
# 5.1,3.5,1.4,0.3,setosa
# 5.7,3.8,1.7,0.3,setosa
# 5.1,3.8,1.5,0.3,setosa
# 5.4,3.4,1.7,0.2,setosa
# 5.1,3.7,1.5,0.4,setosa
# 4.6,3.6,1,0.2,setosa
# 5.1,3.3,1.7,0.5,setosa
# 4.8,3.4,1.9,0.2,setosa
# 5,3,1.6,0.2,setosa
# 5,3.4,1.6,0.4,setosa
# 5.2,3.5,1.5,0.2,setosa
# 5.2,3.4,1.4,0.2,setosa
# 4.7,3.2,1.6,0.2,setosa
# 4.8,3.1,1.6,0.2,setosa
# 5.4,3.4,1.5,0.4,setosa
# 7,3.2,4.7,1.4,versicolor
# 6.4,3.2,4.5,1.5,versicolor
# 6.9,3.1,4.9,1.5,versicolor
# 5.5,2.3,4,1.3,versicolor
# 6.5,2.8,4.6,1.5,versicolor
# 5.7,2.8,4.5,1.3,versicolor
# 6.3,3.3,4.7,1.6,versicolor
# ...

# %% [markdown]
# Then we will pass the information into Varibles

# %%
sepalLenght, sepalWidth, petalLenght, petalWidth, = np.genfromtxt('IRIS.csv', delimiter = ',', usecols = (0,1,2,3), unpack = True, dtype=float)
species = np.genfromtxt('IRIS.csv', delimiter=',', usecols=4, unpack = True, dtype=str)

# %%
plt.scatter(sepalLenght, sepalWidth)              
plt.ylabel('Sepal Widht')                        
plt.xlabel('Sepal Length')                       
plt.title('Sepal Lenght and Width')  

plt.show()

# %% [markdown]
# I redid the plot to make it more complex, this time I paired the flower types with a color

# %%
            
plt.ylabel('Sepal Widht')                        
plt.xlabel('Sepal Length')                       
plt.title('Sepal Lenght and Width')  

pairs={'setosa' :'blue','versicolor' :'Red','virginica' :'Green'}

plt.scatter(sepalLenght, sepalWidth, c=[pairs[i] for i in species], label=[pairs[i] for i in pairs])
labels = [matpat.Patch(color=cs, label=ls) for ls, cs in pairs.items()]

plt.legend(handles = labels)

plt.show()

# %% [markdown]
# Scatterplot Matrix of the Iris Dataset

# %%
sns.set(style="ticks")

df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
plt.show()

# %% [markdown]
# Reference : http://seaborn.pydata.org/examples/scatterplot_matrix.html

# %% [markdown]
# Making sure that the File is reading in, here I am using Pandas to read in the Data

# %%
iris = pd.read_csv('IRIS.csv')
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  setosa
# 0  4.9  3.0  1.4  0.2  setosa
# 1  4.7  3.2  1.3  0.2  setosa
# 2  4.6  3.1  1.5  0.2  setosa
# 3  5.0  3.6  1.4  0.2  setosa
# 4  5.4  3.9  1.7  0.4  setosa

# %% [markdown]
# This is the shape of the dataset

# %%
iris.shape
# Out:
# (99, 5)

# %% [markdown]
# This is what columns it has

# %%
iris.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'setosa'], dtype='object')

# %% [markdown]
# Printing the PetalLenght Numpy Array

# %%
print(petalLenght)
# Out:
# [ 1.4  1.4  1.3  1.5  1.4  1.7  1.4  1.5  1.4  1.5  1.5  1.6  1.4  1.1  1.2
#   1.5  1.3  1.4  1.7  1.5  1.7  1.5  1.   1.7  1.9  1.6  1.6  1.5  1.4  1.6
#   1.6  1.5  4.7  4.5  4.9  4.   4.6  4.5  4.7  3.3  4.6  3.9  3.5  4.2  4.
#   4.7  3.6  4.4  4.5  4.1  4.5  3.9  4.8  4.   4.9  4.7  4.3  4.4  4.8  5.
#   4.5  3.5  3.8  3.7  3.9  5.1  6.   5.1  5.9  5.6  5.8  6.6  4.5  6.3  5.8
#   6.1  5.1  5.3  5.5  5.   5.1  5.3  5.5  6.7  6.9  5.   5.7  4.9  6.7  4.9
#   5.7  6.   4.8  4.9  5.6  5.8  6.1  6.4  5.6  5.1]

# %%
def best_fit_slope(x,y):
    m= (((mean(x) * mean (y)) - mean(x*y)) / ((mean(x) * mean (x)) - mean(x*x)))
    b = mean(y) - m*mean(x)
    return m, b

# %% [markdown]
# Reference: https://pythonprogramming.net

# %% [markdown]
# Calling the best_fit_slope method()

# %%
best_fit_slope(petalLenght, petalWidth)
# Out:
# (0.40280679494463806, -0.33820896733180117)

# %% [markdown]
# Plotting the best fit line

# %%
m,b = best_fit_slope(petalLenght, petalWidth)
bestline = [(m*x)+b for x in petalLenght]

plt.scatter(petalLenght,petalWidth, label = "petals", s=200)
plt.plot(petalLenght, bestline)
plt.xlabel("PetalLenght")
plt.ylabel("PetalWidth")
plt.title("Best Fit Line")
plt.show()

# %% [markdown]
# Best fit line for sepals in setosa

# %%
plt.scatter(petalLenght,petalWidth, label = "Setosa", s=200)
m,b = best_fit_slope(petalLenght, petalWidth)
bestline = [(m*x)+b for x in petalLenght]
plt.plot(petalLenght, bestline)
plt.ylabel('Petal Widht')                        
plt.xlabel('Petal Length') 
plt.legend()
plt.show()
